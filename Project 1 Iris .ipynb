# %% [markdown]
# # Iris DataSet
# ![Jupyter Logo](C:\Users\LENOVO\Downloads\1_YYiQed4kj_EZ2qfg_imDWA.webp)

# %% [markdown]
# In this project, the analysis focused on the Iris flower dataset obtained from [source]. The objective was to explore and classify Iris flower species based on their sepal length, sepal width, petal length, and petal width.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# ### Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\Data Set-20240209T193051Z-001\Data Set\Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Removed 'id' column as it's not adding any significance in result

# %%
df.drop(columns='Id', inplace=True)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### size of data for each class table

# %%
df.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap="cool")
# Out:
# <Axes: >

# %%
df.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.set_style('darkgrid')
sns.scatterplot(data =df ,x = "SepalLengthCm", y = "SepalWidthCm",hue = "Species",style="Species")
plt.title("Sepal Length vs Width")
plt.show()

sns.lineplot(x="SepalLengthCm", y="SepalWidthCm", hue="Species", data=df,)
plt.title(" Sepal Length vs Width")
plt.show()

# %% [markdown]
# ### A scatter plot & Line Plot showing the relationship between the sepal width and length for each iris flower specie
# - The figures above show that Iris setosa has sepal length not greater than 6.0 cm and sepal width not less than 2.3 cm;
# - Iris versicolor has sepal length not less than 5.0 cm and sepal width not greater than 3.4 cm;
# - Iris virginica has sepal length not less than 6.0 cm and sepal width not greater than 3.8 cm.
# - The sepal length and width of Iris setosa is clearly distinct from the other species of Iris flower.

# %%
sns.scatterplot(data =df ,x = "PetalLengthCm", y = "PetalWidthCm",hue ="Species",style="Species")
plt.title(" Petal Length vs Width")
plt.show()

sns.lineplot(x="PetalLengthCm", y="PetalWidthCm", hue="Species", data=df)
plt.title(" Petal Length vs Width")
plt.show()

# %% [markdown]
# ### A scatter plot and  Line Plot showing the relationship between the Petal width and length for each iris flower specie
# - From the figures above, the petal length and width of Iris setosa is again clearly distinct from the others.
# - Iris setosa has petal width and length not greater than 0.6 cm and 2 cm respectively
# - Iris versicolor has petal width and petal length not less than 0.9 cm and 3.5 cm respectively
# - Iris virginica has petal width and petal length not less than 1.3 cm and 4 cm respectively.

# %%
sns.set_style('darkgrid')
sns.pairplot(df, hue='Species', size=3)
plt.show()

# %% [markdown]
# ### Distribution for length and width

# %%
df.hist(edgecolor='black',bins = 26, figsize= (12,6))
plt.show()

# %%
sns.FacetGrid(df, hue='Species', height=4).map(sns.distplot, 'SepalWidthCm').add_legend()
plt.show()

# %% [markdown]
# - We can not separate flowers just using SepalWidthCm

# %%
sns.FacetGrid(df, hue='Species', height=4).map(sns.distplot, 'SepalLengthCm').add_legend()
plt.show()

# %% [markdown]
# - We can not separate flowers just using SepalLengthCm

# %%
sns.FacetGrid(df, hue='Species', height=4).map(sns.distplot, 'PetalLengthCm').add_legend()
plt.show()

# %% [markdown]
# - Just using PetalLength we can separate Iris-setosa flowers easily.
# - Also Iris-versicolor and Iris-virginica partially seperated

# %%
sns.FacetGrid(df, hue='Species', height=4).map(sns.distplot, 'PetalWidthCm').add_legend()
plt.show()

# %% [markdown]
# - We can Iris-setosa is well separable using PetalWidth
# - Iris-versicolor and Iris-virginica are partially separable using PetalWidth

# %%
fig, axis = plt.subplots(2,2, figsize=(11, 6))
sns.violinplot(x='Species', y='SepalLengthCm', data=df, ax=axis[0,0])
sns.violinplot(x='Species', y='SepalWidthCm', data=df, ax=axis[0,1])
sns.violinplot(x='Species', y='PetalLengthCm', data=df, ax=axis[1,0])
sns.violinplot(x='Species', y='PetalWidthCm', data=df, ax=axis[1,1])
plt.show()

# %%
fig, axis = plt.subplots(2, 2, figsize=(11,6))
sns.boxplot(x='Species', y='SepalLengthCm', data=df, ax=axis[0,0])
sns.boxplot(x='Species', y='SepalWidthCm', data=df, ax=axis[0,1])
sns.boxplot(x='Species', y='PetalLengthCm', data=df, ax=axis[1,0])
sns.boxplot(x='Species', y='PetalWidthCm', data=df, ax=axis[1,1])
plt.show()

# %% [markdown]
# ### This box plot provides valuable insights into the feature variations among the three iris species, aiding in species classification and understanding their distinct characteristics.
# ### Sepal Length:
# - The sepal length of Iris-setosa (blue box) is the shortest, with a median value around 5.0 cm.
# - Iris-versicolor (orange box) and Iris-virginica (green box) have similar median sepal lengths, around 5.9 cm.
# - There are a few outliers in the sepal length of Iris-virginica.
# ### Sepal Width:
# - Iris-setosa has the widest sepal width, with a median value around 3.4 cm.
# - Iris-versicolor and Iris-virginica exhibit similar sepal width distributions, centered around 2.8 cm.
# - Some outliers exist in both Iris-versicolor and Iris-virginica.
# ### Petal Length:
# - Iris-setosa has the shortest petal length, with a median value around 1.5 cm.
# - Iris-versicolor and Iris-virginica share similar median petal lengths, approximately 4.4 cm.
# - No significant outliers are observed.
# ### Petal Width:
# - Iris-setosa has the narrowest petal width, with a median value around 0.2 cm.
# - Iris-versicolor and Iris-virginica exhibit similar petal width distributions, centered around 1.3 cm.
# - A few outliers are present in both species.
